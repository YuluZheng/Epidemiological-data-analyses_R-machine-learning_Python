# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, GridSearchCV


# generate two class dataset
data = pd.read_csv("10476 - 15 features.csv")
data.tail()
# Out:
#           No  stroke  age    NP    NC   MP  MCHC   UA   GLB  AKP    LP    MCV  \
# 10471  10112       0   80  53.1  1.73  5.9   349  193  27.9   50  38.5   96.1
# 10472  11993       0   80  68.4  4.41  7.3   350  290  28.0   74  20.6   98.0
# 10473  10759       0   80  53.4  3.04  7.9   329  268  22.7   77  37.5  101.0
# 10474   7073       0   80  54.9  2.25  4.9   318  624  25.4   36  26.1  100.0
# 10475   9661       0   80  60.2  4.00  6.4   316  472  30.1   69  26.3   97.0
#
#        Hgb    TP  RDW-DV    TC   HDL
# 10471  156  71.3    12.8  3.88  1.59
# 10472  154  71.1    12.1  4.59  1.60
# 10473  137  64.1    14.2  5.44  1.83
# 10474  117  66.5    13.3  4.21  1.93
# 10475  164  72.4    14.6  6.50  1.96

# %%
data=data.drop(['No'],axis=1)
# Split target and features
X = data.drop(['stroke'],axis=1)
X
y = data['stroke']
y = y.astype(int)
y
print(X.shape)
print(y.shape)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

# first one
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8,test_size=0.2, random_state=5)
# Out:
# (10476, 15)
# (10476,)

# %%
# train models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.linear_model import ElasticNet
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB

# logistic regression
model1 = LogisticRegression()
# knn
model2 = KNeighborsClassifier()
# RF
model3 = RandomForestClassifier()
# XGBoost
model4 = XGBClassifier()

# GaussianNB
model5=GaussianNB()

# neural network
model6 = MLPClassifier()

# fit model
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)
model4.fit(X_train, y_train)
model5.fit(X_train, y_train)
model6.fit(X_train, y_train)
# Out:
# C:\Users\93513\Anaconda3\lib\site-packages\dask\dataframe\utils.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# MLPClassifier()

# %%
# predict probabilities
pred_prob1 = model1.predict_proba(X_test)
pred_prob2 = model2.predict_proba(X_test)
pred_prob3 = model3.predict_proba(X_test)
pred_prob4 = model4.predict_proba(X_test)
pred_prob5 = model5.predict_proba(X_test)
pred_prob6 = model6.predict_proba(X_test)

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob3[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob4[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_test, pred_prob5[:,1], pos_label=1)
fpr6, tpr6, thresh6 = roc_curve(y_test, pred_prob6[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
# AUC score can be computed using the roc_auc_score() method of sklearn:

from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
auc_score2 = roc_auc_score(y_test, pred_prob2[:,1])
auc_score3 = roc_auc_score(y_test, pred_prob3[:,1])
auc_score4 = roc_auc_score(y_test, pred_prob4[:,1])
auc_score5 = roc_auc_score(y_test, pred_prob5[:,1])
auc_score6 = roc_auc_score(y_test, pred_prob6[:,1])


print(auc_score1, auc_score2, auc_score3, auc_score4, auc_score5, auc_score6)
# Out:
# 0.8965627768778064 0.8200277185132168 0.9134479408258915 0.9135116824791498 0.8867820754828659 0.90247618111007

# %%
###########
## Tuning the hyper-parameters of an estimator

## Parameter estimation using grid search with cross-validation
###########

# %%
from sklearn.model_selection import GridSearchCV

# model 1 - logistic regression

#tuned_params1 = {'C':[*np.linspace(0.01, 1.1,0.1)]}

C = np.arange(0.01, 1.1,0.1)
tuned_params1 = [{'C': C}]

GS1 = GridSearchCV(model1,tuned_params1,scoring="roc_auc",cv=10)
GS1.fit(X_train,y_train)
print(GS1.best_score_)
print(GS1.best_params_)

# best params: C=0.21, best score AUC=0.89396
# Out:
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# model 2 - KNN
from sklearn.model_selection import GridSearchCV
k_range = range(15,25)
tuned_params2 = [{'n_neighbors': k_range}]

GS2 = GridSearchCV(model2, tuned_params2, scoring='roc_auc', cv=10)

GS2.fit(X_train, y_train)
print(GS2.best_score_)
print(GS2.best_params_)
# Out:
# 0.8469758770676366
# {'n_neighbors': 23}

# %%
k_range_3rd = range(25, 35)
tuned_params2_3rd = [{'n_neighbors': k_range_3rd}]

GS2_3rd = GridSearchCV(model2, tuned_params2_3rd, scoring='roc_auc', cv=10)

GS2_3rd.fit(X_train, y_train)
print(GS2_3rd.best_score_)
print(GS2_3rd.best_params_)
#grid search best parameters for the neighbours are 32，0.890119
# Out:
# 0.8486195601760341
# {'n_neighbors': 33}

# %%
k_range_3rd = range(35, 45)
tuned_params2_3rd = [{'n_neighbors': k_range_3rd}]

GS2_3rd = GridSearchCV(model2, tuned_params2_3rd, scoring='roc_auc', cv=10)

GS2_3rd.fit(X_train, y_train)
print(GS2_3rd.best_score_)
print(GS2_3rd.best_params_)
#grid search best parameters for the neighbours are 42，0.84926
# Out:
# 0.8492691241798254
# {'n_neighbors': 42}

# %%
k_range_4th = range(45, 65)
tuned_params2_4th = [{'n_neighbors': k_range_4th}]

GS2_4th = GridSearchCV(model2, tuned_params2_4th, scoring='roc_auc', cv=10)

GS2_4th.fit(X_train, y_train)
print(GS2_4th.best_score_)
print(GS2_4th.best_params_)
# Out:
# 0.8488212693760341
# {'n_neighbors': 45}

# %%
k_range_5 = range(65, 75)
tuned_params2_5 = [{'n_neighbors': k_range_5}]

GS2_5 = GridSearchCV(model2, tuned_params2_5, scoring='roc_auc', cv=10)

GS2_5.fit(X_train, y_train)
print(GS2_5.best_score_)
print(GS2_5.best_params_)
#grid search best parameters for the neighbours are 51，0.89176336
# Out:
# 0.8479938440854606
# {'n_neighbors': 65}

# %%
# model 3 - RF
from sklearn.model_selection import cross_val_score
scorel = []
for i in range(0,200,10):
    rfc = RandomForestClassifier(n_estimators=i+1,random_state=25)          # n_estimator的取值是1，21，31.....
                                 
    score = cross_val_score(rfc,X_train,y_train,cv=10).mean()
    scorel.append(score)
print(max(scorel),(scorel.index(max(scorel))*10)+1)   #返回最大值的索引，每隔10个数取一个，加1是因为n_estimator加1了
# 打印1 - max(scorel)是打印列表list-scorel中的最大值；2 - #list.index([object]) 返回这个object在列表list中的索引
# plt.figure(figsize=[20,5])    #画布，20：5的比例
# plt.plot(range(0,201,10),scorel)   #横坐标是range 1-201,间隔10；纵坐标是scorel的分数
# plt.show()
# Out:
# 0.8374701670644391 191

# %%
GS3 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(185,187)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3.fit(X_train, y_train)
print(GS3.best_score_)
print(GS3.best_params_)

# 0.9127921282949542
# {'n_estimators': 185}
# Out:
# 0.9127921282949542
# {'n_estimators': 185}

# %%
GS3_2 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(180,185)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3_2.fit(X_train, y_train)
print(GS3_2.best_score_)
print(GS3_2.best_params_)

# 0.9128075555875705
# {'n_estimators': 180}
# Out:
# 0.9128075555875705
# {'n_estimators': 180}

# %%
GS3_3 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(175,180)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3_3.fit(X_train, y_train)
print(GS3_3.best_score_)
print(GS3_3.best_params_)
# Out:
# 0.9128332645847145
# {'n_estimators': 175}

# %%
GS3_4 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(170,175)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3_4.fit(X_train, y_train)
print(GS3_4.best_score_)
print(GS3_4.best_params_)
# Out:
# 0.912848971592066
# {'n_estimators': 174}

# %%
GS3_5 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(190,195)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3_5.fit(X_train, y_train)
print(GS3_5.best_score_)
print(GS3_5.best_params_)
# Out:
# 0.9129658089859864
# {'n_estimators': 194}

# %%
GS3_6 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(195,197)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3_6.fit(X_train, y_train)
print(GS3_6.best_score_)
print(GS3_6.best_params_)
# Out:
# 0.9129872433316859
# {'n_estimators': 196}

# %%
GS3_7 = GridSearchCV(RandomForestClassifier(random_state=25,criterion='entropy')
                   ,{"n_estimators": [*range(197,200)]}
                   ,scoring='roc_auc', cv=10
                  )
GS3_7.fit(X_train, y_train)
print(GS3_7.best_score_)
print(GS3_7.best_params_)

# 0.9130486617738697
# {'n_estimators': 198}
# Final optimal tuned parameters
# Out:
# 0.9130486617738697
# {'n_estimators': 198}

# %%
# model 4 - XGBoost

# %%
tuned_params4 = [{'max_depth': np.arange(3, 10, 2), 'min_child_weight': np.arange(1, 6, 2)}]
GS4 = GridSearchCV(XGBClassifier(learning_rate=0.01, n_estimators=1000, silent=0, gamma=0.2, subsample=0.75, 
                                 objective='binary:logistic', reg_alpha=1, reg_lambda=1,seed=27),
                   param_grid=tuned_params4,
                   scoring='roc_auc', cv=10)
GS4.fit(X_train, y_train)
print(GS4.best_score_)
print(GS4.best_params_)

# 0.9209548726749688
# {'max_depth': 5, 'min_child_weight': 1}
# Out:
# [17:04:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
# ...

# %%
#  model-5 GaussianNB

nb_classifier = GaussianNB()

params_NB = {'var_smoothing': np.logspace(-9,0, num=100)}
gs_NB = GridSearchCV(estimator=nb_classifier, 
                     param_grid=params_NB,  
                     verbose=1, 
                     scoring='roc_auc',cv=10) 
gs_NB.fit(X_train, y_train)

print(gs_NB.best_score_)
print(gs_NB.best_params_)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 0.8865754830200622
# {'var_smoothing': 1.519911082952933e-07}
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    6.4s finished

# %%
# model 6 Neural Network
tuned_params6 = [{'hidden_layer_sizes': range(1, 15, 1), 'alpha': [0.1,0.01,0.001]},]
GS6 = GridSearchCV(model6, param_grid=tuned_params6, scoring='roc_auc', cv=10)
GS6.fit(X_train, y_train)
print(GS6.best_score_)
print(GS6.best_params_)


# 0.8982966495153486
# {'alpha': 0.001, 'hidden_layer_sizes': 14}
# Out:
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\93513\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# ...

# %%
# model 6 Neural Network
tuned_params6_2 = [{'hidden_layer_sizes': range(15, 20, 1), 'alpha': [0.1,0.01,0.001]},]
GS6_2 = GridSearchCV(model6, param_grid=tuned_params6_2, scoring='roc_auc', cv=10)
GS6_2.fit(X_train, y_train)
print(GS6_2.best_score_)
print(GS6_2.best_params_)

# 0.8985858923783588
# {'alpha': 0.001, 'hidden_layer_sizes': 19}
# this is best parameters
# Out:
# 0.8985858923783588
# {'alpha': 0.001, 'hidden_layer_sizes': 19}

# %%
# model 6 Neural Network
tuned_params6_3 = [{'hidden_layer_sizes': range(20, 25, 1), 'alpha': [0.001]},]
GS6_3 = GridSearchCV(model6, param_grid=tuned_params6_3, scoring='roc_auc', cv=10)
GS6_3.fit(X_train, y_train)
print(GS6_3.best_score_)
print(GS6_3.best_params_)
# Out:
# 0.8981144593904684
# {'alpha': 0.001, 'hidden_layer_sizes': 21}
